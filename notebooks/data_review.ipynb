# %%
import pandas as pd

# Read the data from the CSV file
data = pd.read_csv('../data/final_dataset_1.csv')

# Display the data type of each column
print(data.dtypes)
print(data.head())
print(data.describe())
# Out:
# price                     float64
# bedrooms                    int64
# bathrooms                 float64
# sqm_living                float64
# floors                    float64
# condition                   int64
# grade                       int64
# yr_built                    int64
# yr_renovated                int64
# avg_degree                float64
# degree_centrality         float64
# betweenness_centrality    float64
# closeness_centrality      float64
# density                   float64
# sqm_above                 float64
# sqm_basement              float64
# sqm_lot                   float64
# dtype: object
#       price  bedrooms  bathrooms  sqm_living  floors  condition  grade  \
# 0  204148.0         3       1.00   109.62554     1.0          3      7
# 1  494960.0         3       2.25   238.76071     2.0          3      7
# 2  165600.0         2       1.00    71.53531     1.0          3      6
# 3  555680.0         4       3.00   182.08988     1.0          5      7
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data.avg_degree, data.price)
plt.title("Price vs Average Degree")
# Out:
# Text(0.5, 1.0, 'Price vs Average Degree')

# %%
plt.scatter( data.degree_centrality, data.price)
plt.title("Price vs Degree Centrality")
# Out:
# Text(0.5, 1.0, 'Price vs Degree Centrality')

# %%
plt.scatter(data.betweenness_centrality,data.price)
plt.title("Price vs Betweenness Centrality")
# Out:
# Text(0.5, 1.0, 'Price vs Betweenness Centrality')

# %%
plt.scatter(data.closeness_centrality, data.price)
plt.title("Price vs Close Centrality")
# Out:
# Text(0.5, 1.0, 'Price vs Close Centrality')

# %%
plt.scatter(data.density, data.price)
plt.title("Price vs Density")
# Out:
# Text(0.5, 1.0, 'Price vs Density')

# %%
plt.scatter(data.bedrooms, data.price)
plt.title("Price vs Bedrooms")
# Out:
# Text(0.5, 1.0, 'Price vs Bedrooms')

# %%
plt.scatter(data.price,data.sqm_living)
plt.title("Price vs Square Meters Living")
# Out:
# Text(0.5, 1.0, 'Price vs Square Meters Living')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your data from a file (replace 'your_data.csv' with your actual data file)
data = pd.read_csv('../data/final_dataset_1.csv')

# Drop the unnecessary columns
data = data.drop([ 'density', 'yr_renovated',
              'sqm_basement', 'avg_degree','condition'], axis=1)

# Compute the correlation matrix
correlation_matrix = data.corr()

# Generate and display the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
